# %% [markdown]
# #  Exercice pour la prédiction d'un valeur continue

# %% [markdown]
# ## Structure de la rréseau de neurone utilisé

# %% [markdown]
# **Couche d'entré**: 81 neurones
# **couche caché 1**: 200 neurones
# **couche caché 2**: 300 neurones
# **couche caché 3**: 200 neurones
# **couche caché 4**: 100 neurones
# **couche sortie**: 1 neurone

# %% [markdown]
# ### Matrice des données

# %% [markdown]
# $X=(1000,81)$

# %% [markdown]
# ### Matrice poids

# %% [markdown]
# $ W^{[1]} = (81,200) $
# $ W^{[2]} = (200,300) $
# $ W^{[3]} = (300,200) $
# $ W^{[4]} = (200,100) $
# $ W^{[5]} = (100,1) $

# %% [markdown]
# ### Matrice biais

# %% [markdown]
# $ B^{[1]} = (200,1) $
# $ B^{[2]} = (300,1) $
# $ B^{[3]} = (200,1) $
# $ B^{[4]} = (100,1) $
# $ B^{[5]} = (1,1) $

# %% [markdown]
# ### Fonction d'activation utilisé dans chaque couche

# %% [markdown]
# Dans le couche caché, on utilise $ f(x)=max(0,x) $ et dans la couche sortie $ f(x) = x$

# %% [markdown]
# ### Fonction coût

# %% [markdown]
# on utilise la fonction erreur quadratique moyenne **(Mean Squared Error)** $MSE= \frac{1}{n} \sum (y_i-s_i )^2$

# %% [markdown]
# ### Propagation vers l'avant

# %% [markdown]
# $$ Z1= W^{[1]}.X + B^{[1]}$$
# $$ S1=max(0,Z1) $$
#
# $$ Z2= W^{[2]}.S1 + B^{[2]}$$
# $$ S2=max(0,Z2) $$
#
# $$ Z3= W^{[3]}.S2 + B^{[3]}$$
# $$ S3=max(0,Z3) $$
#
# $$ Z4= W^{[4]}.S3 + B^{[4]}$$
# $$ S4=max(0,Z4) $$
#
# $$ Z5= W^{[5]}.S4 + B^{[5]}$$
# $$ S5=Z5 $$

# %% [markdown]
# ### Calcul dérivée de la fonction de coût par rapport à chaque poids

# %% [markdown]
# Dérivée $MSE$ par rapport à $ W^{[5]}$ et  $ B^{[5]}$

# %% [markdown]
# $$(1) =>\frac{\partial (MSE)}{\partial W^{[5]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial W^{[5]}}$$
#
# $$(1)^{'} =>\frac{\partial (MSE)}{\partial B^{[5]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial B^{[5]}}$$

# %% [markdown]
# Dérivée $MSE$ par rapport à $ W^{[4]}$ et  $ B^{[4]}$

# %% [markdown]
# $$ (2)=> \frac{\partial (MSE)}{\partial W^{[4]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial S^{[4]}} . \frac{\partial S^{[4]}}{\partial Z^{[4]}} .\frac{\partial Z^{[4]}}{\partial W^{[4]}}$$
# $$ (2)^{'}=> \frac{\partial (MSE)}{\partial B^{[4]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial S^{[4]}} . \frac{\partial S^{[4]}}{\partial Z^{[4]}} .\frac{\partial Z^{[4]}}{\partial B^{[4]}}$$

# %% [markdown]
# Dérivée $MSE$ par rapport à $ W^{[3]}$ et  $ B^{[3]}$

# %% [markdown]
# $$ (3)=>\frac{\partial (MSE)}{\partial W^{[3]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial S^{[4]}} . \frac{\partial S^{[4]}}{\partial Z^{[4]}} .\frac{\partial Z^{[4]}}{\partial S^{[3]}}.\frac{\partial S^{[3]}}{\partial Z^{[3]}}.\frac{\partial Z^{[3]}}{\partial W^{[3]}}$$
# $$ (3)^{'}=>\frac{\partial (MSE)}{\partial B^{[3]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial S^{[4]}} . \frac{\partial S^{[4]}}{\partial Z^{[4]}} .\frac{\partial Z^{[4]}}{\partial S^{[3]}}.\frac{\partial S^{[3]}}{\partial Z^{[3]}}.\frac{\partial Z^{[3]}}{\partial B^{[3]}}$$

# %% [markdown]
# Dérivée $MSE$ par rapport à $ W^{[2]}$ et  $ B^{[2]}$

# %% [markdown]
# $$ (4)=>\frac{\partial (MSE)}{\partial W^{[2]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial S^{[4]}} . \frac{\partial S^{[4]}}{\partial Z^{[4]}} .\frac{\partial Z^{[4]}}{\partial S^{[3]}}.\frac{\partial S^{[3]}}{\partial Z^{[3]}}.\frac{\partial Z^{[3]}}{\partial S^{[2]}}.\frac{\partial S^{[2]}}{\partial Z^{[2]}}.\frac{\partial Z^{[2]}}{\partial W^{[2]}}$$
# $$ (4)^{'}=>\frac{\partial (MSE)}{\partial B^{[2]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial S^{[4]}} . \frac{\partial S^{[4]}}{\partial Z^{[4]}} .\frac{\partial Z^{[4]}}{\partial S^{[3]}}.\frac{\partial S^{[3]}}{\partial Z^{[3]}}.\frac{\partial Z^{[3]}}{\partial S^{[2]}}.\frac{\partial S^{[2]}}{\partial Z^{[2]}}.\frac{\partial Z^{[2]}}{\partial B^{[2]}}$$

# %% [markdown]
# Dérivée $MSE$ par rapport à $ W^{[1]}$ et  $ B^{[1]}$

# %% [markdown]
# $$ (5)=>\frac{\partial (MSE)}{\partial W^{[1]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial S^{[4]}} . \frac{\partial S^{[4]}}{\partial Z^{[4]}} .\frac{\partial Z^{[4]}}{\partial S^{[3]}}.\frac{\partial S^{[3]}}{\partial Z^{[3]}}.\frac{\partial Z^{[3]}}{\partial S^{[2]}}.\frac{\partial S^{[2]}}{\partial Z^{[2]}}.\frac{\partial Z^{[2]}}{\partial S^{[1]}}.\frac{\partial S^{[1]}}{\partial Z^{[1]}}.\frac{\partial Z^{[1]}}{\partial W^{[1]}}$$
#
# $$ (5)^{'}=>\frac{\partial (MSE)}{\partial B^{[1]} } = \frac{\partial (MSE)}{\partial S^{[5]}} . \frac{\partial S^{[5]}}{\partial Z^{[5]}}. \frac{\partial Z^{[5]}}{\partial S^{[4]}} . \frac{\partial S^{[4]}}{\partial Z^{[4]}} .\frac{\partial Z^{[4]}}{\partial S^{[3]}}.\frac{\partial S^{[3]}}{\partial Z^{[3]}}.\frac{\partial Z^{[3]}}{\partial S^{[2]}}.\frac{\partial S^{[2]}}{\partial Z^{[2]}}.\frac{\partial Z^{[2]}}{\partial S^{[1]}}.\frac{\partial S^{[1]}}{\partial Z^{[1]}}.\frac{\partial Z^{[1]}}{\partial B^{[1]}}$$

# %% [markdown]
# **Calcul de l'equation $(1)$ et $ (1)^{'}$**

# %% [markdown]
# $$ d^{[1]} = (S^{[5]}-Y)$$
# $$ \frac{\partial (MSE)}{\partial W^{[5]} } =  \frac{2}{n} d^{[1]}.S^{[4]}$$
# $$ \frac{\partial (MSE)}{\partial B^{[5]} } =  \frac{2}{n} \sum  d^{[1]} $$

# %% [markdown]
# **Calcul de l'equation $(2)$ et $ (2)^{'}$**

# %% [markdown]
# $$ d^{[2]} = d^{[1]}.W^{[5]}.max(0,1) $$ $ 0 $ si $ z_{4} < 0 $
# $$ \frac{\partial (MSE)}{\partial W^{[4]} } =  \frac{2}{n} d^{[2]}.S^{[3]}$$
# $$ \frac{\partial (MSE)}{\partial B^{[4]} } =  \frac{2}{n} \sum  d^{[2]} $$

# %% [markdown]
# **Calcul de l'equation $(3)$ et $ (3)^{'}$**

# %% [markdown]
# $$ d^{[3]} = d^{[2]}.W^{[4]}.max(0,1) $$ $ 0 $ si $ z_{3} < 0 $
# $$ \frac{\partial (MSE)}{\partial W^{[3]} } =  \frac{2}{n} d^{[3]}.S^{[2]}$$
# $$ \frac{\partial (MSE)}{\partial B^{[3]} } =  \frac{2}{n} \sum  d^{[3]} $$

# %% [markdown]
# **Calcul de l'equation $(4)$ et $ (4)^{'}$**

# %% [markdown]
# $$ d^{[4]} = d^{[3]}.W^{[3]}.max(0,1) $$ $ 0 $ si $ z_{2} < 0 $
# $$ \frac{\partial (MSE)}{\partial W^{[2]} } =  \frac{2}{n} d^{[4]}.S^{[1]}$$
# $$ \frac{\partial (MSE)}{\partial B^{[2]} } =  \frac{2}{n} \sum  d^{[4]} $$

# %% [markdown]
# **Calcul de l'equation $(5)$ et $ (5)^{'}$**

# %% [markdown]
# $$ d^{[5]} = d^{[4]}.W^{[2]}.max(0,1) $$ $ 0 $ si $ z_{1} < 0 $
# $$ \frac{\partial (MSE)}{\partial W^{[1]} } =  \frac{2}{n} d^{[5]}.X$$
# $$ \frac{\partial (MSE)}{\partial B^{[1]} } =  \frac{2}{n} \sum  d^{[5]} $$

# %% [markdown]
# ### Descente de gradient

# %% [markdown]
# $$ W^{[n]}_{i+1}=W^{[n]}_{i}-\eta \frac{\partial (LL)}{\partial W^{[n]}} $$
# $$ B^{[n]}_{i+1}=B^{[n]}_{i}-\eta \frac{\partial (LL)}{\partial B^{[n]}} $$

# %% [markdown]
# ### Programmation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Lire les données depuis un fichier CSV
df = pd.read_csv('data/regression_train.csv',low_memory=False)

data_out=df['critical_temp']

data_in=df[['number_of_elements',
            'mean_atomic_mass',
            'wtd_mean_atomic_mass',
            'gmean_atomic_mass',
            'wtd_gmean_atomic_mass',
            'entropy_atomic_mass',
            'wtd_entropy_atomic_mass',
            'range_atomic_mass',
            'wtd_range_atomic_mass',
            'std_atomic_mass',
            'wtd_std_atomic_mass',
            'mean_fie',
            'wtd_mean_fie',
            'gmean_fie',
            'wtd_gmean_fie',
            'entropy_fie',
            'wtd_entropy_fie',
            'range_fie',
            'wtd_range_fie',
            'std_fie',
            'wtd_std_fie',
            'mean_atomic_radius',
            'wtd_mean_atomic_radius',
            'gmean_atomic_radius',
            'wtd_gmean_atomic_radius',
            'entropy_atomic_radius',
            'wtd_entropy_atomic_radius',
            'range_atomic_radius',
            'wtd_range_atomic_radius',
            'std_atomic_radius',
            'wtd_std_atomic_radius',
            'mean_Density',
            'wtd_mean_Density',
            'gmean_Density',
            'wtd_gmean_Density',
            'entropy_Density',
            'wtd_entropy_Density',
            'range_Density',
            'wtd_range_Density',
            'std_Density',
            'wtd_std_Density',
            'mean_ElectronAffinity',
            'wtd_mean_ElectronAffinity',
            'gmean_ElectronAffinity',
            'wtd_gmean_ElectronAffinity',
            'entropy_ElectronAffinity',
            'wtd_entropy_ElectronAffinity',
            'range_ElectronAffinity',
            'wtd_range_ElectronAffinity',
            'std_ElectronAffinity',
            'wtd_std_ElectronAffinity',
            'mean_FusionHeat',
            'wtd_mean_FusionHeat',
            'gmean_FusionHeat',
            'wtd_gmean_FusionHeat',
            'entropy_FusionHeat',
            'wtd_entropy_FusionHeat',
            'range_FusionHeat',
            'wtd_range_FusionHeat',
            'std_FusionHeat',
            'wtd_std_FusionHeat',
            'mean_ThermalConductivity',
            'wtd_mean_ThermalConductivity',
            'gmean_ThermalConductivity',
            'wtd_gmean_ThermalConductivity',
            'entropy_ThermalConductivity',
            'wtd_entropy_ThermalConductivity',
            'range_ThermalConductivity',
            'wtd_range_ThermalConductivity',
            'std_ThermalConductivity',
            'wtd_std_ThermalConductivity',
            'mean_Valence',
            'wtd_mean_Valence',
            'gmean_Valence',
            'wtd_gmean_Valence',
            'entropy_Valence',
            'wtd_entropy_Valence',
            'range_Valence',
            'wtd_range_Valence',
            'std_Valence',
            'wtd_std_Valence'
]]
X=data_in
Y=data_out.tolist()
Y=np.array([Y])

# %% [markdown]
# **Matrice des poids**

# %%
# Initialisation des matrices de poids et de biais
# Dimensions: (nombre de neurones dans la couche suivante, nombre de neurones dans la couche actuelle)
W1 = np.random.uniform(low=-1, high=1, size=(200, 81))
W2 = np.random.uniform(low=-1, high=1, size=(300, 200))
W3 = np.random.uniform(low=-1, high=1, size=(200, 300))
W4 = np.random.uniform(low=-1, high=1, size=(100, 200))
W5 = np.random.uniform(low=-1, high=1, size=(1, 100))

B1 = np.zeros((200, 1))
B2 = np.zeros((300, 1))
B3 = np.zeros((200, 1))
B4 = np.zeros((100, 1))
B5 = np.zeros((1, 1))

# %% [markdown]
# **Fonction utilisé**

# %%
#Fonction ReLu
def reLU(Z):
    return np.where(Z<0,0,Z)

# Propagation linéaire
def linear(W, S, B):
    return np.dot(W, S) + B

def reLuDerivate(Z):
    return np.where(Z<0,0,1)

# %% [markdown]
# **Propagation vers l'avant**

# %%
# Propagation vers l'avant
def forward_propagation(X, W1, W2, W3, W4,W5, B1, B2, B3, B4,B5):

    Z1 = linear(W1, X.T, B1)
    S1 = reLU(Z1)

    Z2 = linear(W2, S1, B2)
    S2 = reLU(Z2)
    
    Z3 = linear(W3, S2, B3)
    S3 = reLU(Z3)
    
    Z4 = linear(W4, S3, B4)
    S4 = reLU(Z4)

    Z5=linear(W5,S4,B5)
    S5=Z5
    
    
    return S1, S2, S3, S4,S5

# %% [markdown]
# **Fonction coût**

# %%
# Fonction coût mse
def mse(S, Y):
    n = Y.shape[1]
    mse = (1 / n) * np.sum((Y-S)**2)
    return mse

# %% [markdown]
# **Propagation vers l'arrière**

# %%
# Calcul des dérivées pour la descente de gradient
def back_propagation(S1, S2, S3, S4,S5, W1, W2, W3, W4,W5, X, Y):
    m = Y.shape[0]  # Nombre d'exemples
    n=2/m
    d5 = S5 - Y
    DW5 = n * np.dot(d5, S4.T)
    DB5 = n * np.sum(d5)

    d4 = np.dot(d5.T, W5).T * reLuDerivate(S4)  # Gradient de ReLU
    DW4 = n * np.dot(d4, S3.T)
    DB4 = n * np.sum(d4)

    d3 = np.dot(d4.T, W4).T * reLuDerivate(S3)  # Gradient de ReLU
    DW3 = n* np.dot(d3, S2.T)
    DB3 = n * np.sum(d3)

    d2 = np.dot(d3.T, W3).T * reLuDerivate(S2)  # Gradient de ReLU
    DW2 = n * np.dot(d2, S1.T)
    DB2 = n* np.sum(d2)

    d1 = np.dot(d2.T, W2).T * reLuDerivate(S1)  # Gradient de ReLU
    DW1 = n * np.dot(d1, X)
    DB1 = n * np.sum(d1)

    return DW1, DB1, DW2, DB2, DW3, DB3, DW4, DB4, DW5, DB5

# %% [markdown]
# **Propagation vers l'arrière**

# %%
def update_parameters(X, Y, W1, B1, W2, B2, W3, B3, W4, B4, W5, B5, DW1, DB1, DW2, DB2, DW3, DB3, DW4, DB4, DW5, DB5, learning_rate=0.01, n=10):
    data_cost = []
    for i in range(n):
        S1, S2, S3, S4, S5 = forward_propagation(X, W1, W2, W3, W4, W5, B1, B2, B3, B4, B5)
        # Calcul de la fonction coût
        cost = mse(S5.T, Y)
        data_cost.append(cost)
        
        print(f"Iteration {i+1}/{n}, mse: {float(cost)}")
        
        # Propagation vers l'arrière
        DW1, DB1, DW2, DB2, DW3, DB3, DW4, DB4, DW5, DB5 = back_propagation(S1, S2, S3, S4, S5, W1, W2, W3, W4, W5, X, Y)

        # Mise à jour des paramètres
        W1 -= learning_rate * DW1
        B1 -= learning_rate * DB1

        W2 -= learning_rate * DW2
        B2 -= learning_rate * DB2

        W3 -= learning_rate * DW3
        B3 -= learning_rate * DB3

        W4 -= learning_rate * DW4
        B4 -= learning_rate * DB4

        W5 -= learning_rate * DW5
        B5 -= learning_rate * DB5
    
    return W1, B1, W2, B2, W3, B3, W4, B4, W5, B5, data_cost, S5

# %%
S1, S2, S3, S4,S5= forward_propagation(X, W1, W2, W3, W4,W5, B1, B2, B3, B4,B5)

DW1, DB1, DW2, DB2, DW3, DB3, DW4, DB4,DW5,DB5=back_propagation(S1, S2, S3, S4,S5, W1, W2, W3, W4,W5, X, Y)
# Mise à jour des paramètres
W1,B1,W2,B2,W3,B3,W4,B4,W5,B5,data_cost,y_pred = update_parameters(X,Y,W1, B1, W2, B2, W3, B3, W4, B4,W5,B5, DW1, DB1, DW2, DB2, DW3, DB3, DW4, DB4,DW5,DB5,0.01,10)
# Out:
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 1/10, mse: nan
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 2/10, mse: nan
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 3/10, mse: nan
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 4/10, mse: nan
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 5/10, mse: nan
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 6/10, mse: nan
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 7/10, mse: nan
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 8/10, mse: nan
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 9/10, mse: nan
# dd       number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                      4         88.944468             57.862692
# 1                      5         92.729214             58.518416
# 2                      4         88.944468             57.885242
# 3                      4         88.944468             57.873967
# 4                      4         88.944468             57.840143
# ...                  ...               ...                   ...
# 1878                   6        120.375212            112.949451
# 1879                   6        120.375212            113.774536
# 1880                   6        120.375212            114.599620
# 1881                   6        120.375212            115.424705
# 1882                   5        112.032234             69.228205
#
#       gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0             66.361592              36.116612             1.181795
# 1             73.132787              36.396602             1.449309
# 2             66.361592              36.122509             1.181795
# 3             66.361592              36.119560             1.181795
# 4             66.361592              36.110716             1.181795
# ...                 ...                    ...                  ...
# 1878          90.122861              84.212183             1.588258
# 1879          90.122861              84.849300             1.588258
# 1880          90.122861              85.491237             1.588258
# 1881          90.122861              86.138031             1.588258
# 1882          83.104113              39.923454             1.406765
#
#       wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                    1.062396          122.90607              31.794921
# 1                    1.057755          122.90607              36.161939
# 2                    0.975980          122.90607              35.741099
# 3                    1.022291          122.90607              33.768010
# 4                    1.129224          122.90607              27.848743
# ...                       ...                ...                    ...
# 1878                 1.154776          192.98100              63.862035
# 1879                 1.276254          192.98100              60.027553
# 1880                 1.367299          192.98100              56.544547
# 1881                 1.437592          192.98100              53.061540
# 1882                 1.410743          188.38390              21.309362
#
#       std_atomic_mass  ...  mean_Valence  wtd_mean_Valence  gmean_Valence  \
# 0           51.968828  ...          2.25          2.257143       2.213364
# 1           47.094633  ...          2.00          2.257143       1.888175
# 2           51.968828  ...          2.25          2.271429       2.213364
# 3           51.968828  ...          2.25          2.264286       2.213364
# 4           51.968828  ...          2.25          2.242857       2.213364
# ...               ...  ...           ...               ...            ...
# 1878        71.797826  ...          3.00          3.000000       2.798166
# 1879        71.797826  ...          3.00          3.000000       2.798166
# 1880        71.797826  ...          3.00          3.000000       2.798166
# 1881        71.797826  ...          3.00          3.000000       2.798166
# 1882        65.519364  ...          2.40          2.144444       2.352158
#
#       wtd_gmean_Valence  entropy_Valence  wtd_entropy_Valence  range_Valence  \
# 0              2.219783         1.368922             1.066221              1
# 1              2.210679         1.557113             1.047221              2
# 2              2.232679         1.368922             1.029175              1
# 3              2.226222         1.368922             1.048834              1
# 4              2.206963         1.368922             1.096052              1
# ...                 ...              ...                  ...            ...
# 1878           2.722678         1.721089             1.306752              3
# 1879           2.730964         1.721089             1.408485              3
# 1880           2.739276         1.721089             1.487708              3
# 1881           2.747612         1.721089             1.551428              3
# 1882           2.120632         1.589027             1.313784              1
#
#       wtd_range_Valence  std_Valence  wtd_std_Valence
# 0              1.085714     0.433013         0.437059
# 1              1.128571     0.632456         0.468606
# 2              1.114286     0.433013         0.444697
# 3              1.100000     0.433013         0.440952
# 4              1.057143     0.433013         0.428809
# ...                 ...          ...              ...
# 1878           1.533333     1.154701         1.390444
# 1879           1.400000     1.154701         1.366260
# 1880           1.266667     1.154701         1.341641
# 1881           1.133333     1.154701         1.316561
# 1882           1.011111     0.489898         0.351540
#
# [1883 rows x 81 columns]
# Iteration 10/10, mse: nan
